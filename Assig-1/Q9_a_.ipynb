# %%
#imortimg Modules
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import norm

# %%
df = pd.read_csv('C:\\Users\\nanir\\OneDrive\\excelR\\Assignments\\Assig-1\\Q9_a.csv')
print(df.head(4))
df.dtypes # Data type of columns values
# Out:
#    Index  speed  dist
# 0      1      4     2
# 1      2      4    10
# 2      3      7     4
# 3      4      7    22
# Index    int64
# speed    int64
# dist     int64
# dtype: object

# %%
skewness =[df.skew(axis=0)[i] for i in range(1,3)]
skewness
# Out:
# [-0.11750986144663393, 0.8068949601674215]

# %%
Kurtosis =[df.kurt(axis=0)[i] for i in range(1,3)]
Kurtosis
# Out:
# [-0.5089944204057617, 0.4050525816795765]

# %%
dict={'Skewness':skewness,'Kurtosis':Kurtosis}
df1=pd.DataFrame(dict)
df1.rename(index={0:'Speed',1:'Distance'},inplace = True)
#df1.to_excel('Q9_a.xlsx')

# %%
plt.figure(figsize=(16,9))
sns.set()
sns.displot(df['dist'], kde=True,bins = 30)
plt.title("Histogram of Distance") # for histogram title
sns.displot(df['speed'], kde = True,bins = 30)
plt.title("Histogram of Speed") # for histogram title
# Out:
# Text(0.5, 1.0, 'Histogram of Speed')
