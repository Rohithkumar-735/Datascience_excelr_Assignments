# %%
#imortimg Modules
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import norm

# %%
df = pd.read_csv('C:\\Users\\nanir\\OneDrive\\excelR\\Assignments\\Assig-1\\Q9_b.csv')
print(df.head(10))
df.dtypes # Data type of columns values
# Out:
#    Unnamed: 0          SP         WT
# 0           1  104.185353  28.762059
# 1           2  105.461264  30.466833
# 2           3  105.461264  30.193597
# 3           4  113.461264  30.632114
# 4           5  104.461264  29.889149
# 5           6  113.185353  29.591768
# 6           7  105.461264  30.308480
# 7           8  102.598513  15.847758
# 8           9  102.598513  16.359484
# 9          10  115.645204  30.920154
# Unnamed: 0      int64
# SP            float64
# WT            float64
# dtype: object

# %%
skewness =[df.skew(axis=0)[i] for i in range(1,3)]
skewness
# Out:
# [1.6114501961773586, -0.6147533255357768]

# %%
Kurtosis =[df.kurt(axis=0)[i] for i in range(1,3)]
Kurtosis
# Out:
# [2.9773289437871835, 0.9502914910300326]

# %%
dict={'Skewness':skewness,'Kurtosis':Kurtosis}
df1=pd.DataFrame(dict)
df1.rename(index={0:'SP',1:'WT'},inplace = True)
#df1.to_excel('Q9_b.xlsx')

# %%
plt.figure(figsize=(16,9))
sns.set()
sns.displot(df['SP'], kde=True,bins = 30)
plt.title("Histogram of SP") # for histogram title
sns.displot(df['WT'], kde = True,bins = 30)
plt.title("Histogram of WT") # for histogram title
# Out:
# Text(0.5, 1.0, 'Histogram of WT')
